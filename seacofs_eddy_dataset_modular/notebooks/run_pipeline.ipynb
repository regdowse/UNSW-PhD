# %% [markdown]
# # SEACOFS Eddy Dataset Pipeline
#
# This notebook is a concise control panel for the modular SEACOFS eddy dataset pipeline. The scientific functions live in `src/seacofs_eddy_dataset/`; this notebook only loads config, runs stages, and checks outputs.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().resolve()
if PROJECT_ROOT.name == "notebooks":
    PROJECT_ROOT = PROJECT_ROOT.parent

SRC = PROJECT_ROOT / "src"
if str(SRC) not in sys.path:
    sys.path.insert(0, str(SRC))

PROJECT_ROOT
# Out:
# PosixPath('/home/z5297792/UNSW-MRes/MRes/seacofs_eddy_dataset_modular')

# %% [markdown]
# ## Load Config
#
# Copy `config/example.yaml` to `config/local.yaml` and edit paths before running the pipeline.

# %%
from seacofs_eddy_dataset.config import load_config
from seacofs_eddy_dataset.pipeline import STAGES, run_stage, run_all

CONFIG_PATH = PROJECT_ROOT / "config" / "local.yaml"
config = load_config(CONFIG_PATH)

config.output_root
# Out:
# PosixPath('/srv/scratch/z5297792/SEACOFS_26yr_eddy_dataset_modular')

# %%
[(stage.name, stage.description) for stage in STAGES]
# Out:
# [('detect_nencioli', 'Detect surface eddy candidates with Nencioli.'),
#  ('fit_doppio_surface', 'Fit DOPPIO surface eddy parameters.'),
#  ('track_eddies', 'Link surface eddies into time-continuous tracks.'),
#  ('process_tracked_dataset', 'Clean tracked eddy dataset.'),
#  ('compute_vertical_profiles', 'Compute vertical profiles by eddy-day.'),
#  ('qc_vertical_profiles', 'Confirm usable vertical profiles.'),
#  ('compute_tilt', 'Compute tilt metrics from confirmed vertical profiles.'),
#  ('analyse_tilt', 'Produce tilt summaries, tables, and figures.')]

# %% [markdown]
# ## Run Individual Stages
#
# Run any single stage while developing or resuming part of the workflow.

# %%
# run_stage("detect_nencioli", config)

# %% [markdown]
# ## Run The Workflow
#
# Edit this list if you want to resume from a later stage or stop before analysis.

# %%
STAGES_TO_RUN = [
    # "detect_nencioli",
    # "fit_doppio_surface",
    # "track_eddies",
    # "process_tracked_dataset",
    # "compute_vertical_profiles",
    "qc_vertical_profiles",
    "compute_tilt",
    # "analyse_tilt",
]

for stage_name in STAGES_TO_RUN:
    run_stage(stage_name, config)
# Out:
# /srv/scratch/z5297792/SEACOFS_26yr_eddy_dataset_modular/vertical_profiles_confirmed/profiles.parquet
# /srv/scratch/z5297792/SEACOFS_26yr_eddy_dataset_modular/tilt/tilt_dataset.parquet

# %% [markdown]
# ## Inspect Outputs

# %%
import pandas as pd

output_dirs = {
    "detections": config.output_root / "detections",
    "surface_eddies": config.output_root / "surface_eddies",
    "tracked": config.output_root / "tracked",
    "processed": config.output_root / "processed",
    "vertical_profiles": config.output_root / "vertical_profiles",
    "vertical_profiles_confirmed": config.output_root / "vertical_profiles_confirmed",
    "tilt": config.output_root / "tilt",
    "analysis": config.output_root / "analysis",
}

pd.DataFrame(
    [
        {"stage": name, "path": str(path), "parquet_files": len(list(path.glob("*.parquet"))) if path.exists() else 0}
        for name, path in output_dirs.items()
    ]
)
# Out:
#                          stage  \
# 0                   detections
# 1               surface_eddies
# 2                      tracked
# 3                    processed
# 4            vertical_profiles
# 5  vertical_profiles_confirmed
# 6                         tilt
# 7                     analysis
#
#                                                 path  parquet_files
# 0  /srv/scratch/z5297792/SEACOFS_26yr_eddy_datase...            307
# 1  /srv/scratch/z5297792/SEACOFS_26yr_eddy_datase...            307
# 2  /srv/scratch/z5297792/SEACOFS_26yr_eddy_datase...              1
# 3  /srv/scratch/z5297792/SEACOFS_26yr_eddy_datase...              1
# 4  /srv/scratch/z5297792/SEACOFS_26yr_eddy_datase...            307
# 5  /srv/scratch/z5297792/SEACOFS_26yr_eddy_datase...              1
# 6  /srv/scratch/z5297792/SEACOFS_26yr_eddy_datase...              1
# 7  /srv/scratch/z5297792/SEACOFS_26yr_eddy_datase...              2

# %%
detection_files = sorted((config.output_root / "detections").glob("fnumber=*.parquet"))

if detection_files:
    df_detect = pd.concat((pd.read_parquet(path) for path in detection_files), ignore_index=True)
    display(df_detect.head())
    display(df_detect.groupby("Cyc").size().rename("count"))
    display(df_detect.groupby("fnumber").size().rename("detections").describe())
else:
    print(f"No detection files found in {config.output_root / 'detections'}")
# Out:
#     Day    nxc     nyc Cyc  nic  njc  fnumber
# 0  1462  830.0  1515.0  AE  245  307     1461
# 1  1462  358.0  1408.0  AE  136  285     1461
# 2  1462  928.0  1356.0  CE  261  274     1461
# 3  1462  506.0  1354.0  CE  179  274     1461
# 4  1462  754.0  1285.0  AE  231  260     1461
# Cyc
# AE    204657
# CE    210292
# Name: count, dtype: int64
# count     307.000000
# mean     1351.625407
# std       300.749836
# min       272.000000
# 25%      1136.000000
# 50%      1272.000000
# 75%      1528.500000
# max      2332.000000
# Name: detections, dtype: float64

# %% [markdown]
# ## Run Everything
#
# Equivalent shortcut for the full sequence.

# %%
# run_all(config)
